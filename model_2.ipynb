# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# ...

# %% [markdown]
# # Select your features (columns)

# %%
data= pd.get_dummies(df)
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_slogg_err2  koi_srad  koi_srad_err1  \
# ...

# %%
# Set features. This will also be used as your x values.
selected_features = data[['koi_period', 'koi_time0bk', 'koi_slogg', 'koi_srad', 'ra', 'dec', 'koi_kepmag','koi_disposition_CANDIDATE']]
renamed_df= selected_features.rename(columns={'koi_period':'Period', 'koi_time0bk':'Time', 'koi_slogg':'Slogg', 'koi_srad':'Srad', 'ra':'RA', 'dec':'DEC', 'koi_kepmag':'Kepmag', 'koi_disposition_CANDIDATE':'Kepler Disposition'})

renamed_df.head()
# Out:
#       Period        Time  Slogg   Srad         RA        DEC  Kepmag  \
# 0  54.418383  162.513840  4.467  0.927  291.93423  48.141651  15.347
# 1  19.899140  175.850252  4.544  0.868  297.00482  48.134129  15.436
# 2   1.736952  170.307565  4.564  0.791  285.53461  48.285210  15.597
# 3   2.525592  171.595550  4.438  1.046  288.75488  48.226200  15.509
# 4   4.134435  172.979370  4.486  0.972  296.28613  48.224670  15.714
#
#    Kepler Disposition
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X= renamed_df.drop('Kepler Disposition', axis=1)
y= renamed_df['Kepler Disposition'].values.reshape(-1, 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

X_train.head()
# Out:
#           Period        Time  Slogg   Srad         RA        DEC  Kepmag
# 3563   10.548413  139.064020  4.387  1.092  298.09543  44.737061  13.204
# 4099   24.754385  140.207320  4.519  0.804  295.73535  42.576248  15.514
# 5460    1.057336  131.792007  4.594  0.683  292.18417  49.310040  15.414
# 1091  201.118319  187.569860  4.447  0.954  283.11377  48.131390  13.328
# 5999   91.649983  175.715600  4.145  1.608  294.93198  39.812420  12.964

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %% [markdown]
# # Train the Model

# %%
# Create the GridSearchCV model
from sklearn.svm import SVC 
model2 = SVC(kernel='linear')

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Train the model with GridSearch
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [1, 5, 10],
              'gamma': [0.0001, 0.001, 0.01]}
grid = GridSearchCV(model2, param_grid, verbose=3)

# %%
grid.fit(X_train, y_train)
predictions = grid.predict(X_test)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# C:\Users\Nasrin\AppData\Roaming\Python\Python39\site-packages\sklearn\utils\validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# # Save the Model

# %%
import joblib
filename = 'Nasrin_Dehghan2.sav'
joblib.dump(model2, filename)
# Out:
# ['Nasrin_Dehghan2.sav']
